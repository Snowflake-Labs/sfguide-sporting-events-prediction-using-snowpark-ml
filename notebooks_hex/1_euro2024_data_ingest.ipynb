# %%
import pandas as _hex_pandas
import datetime as _hex_datetime
import json as _hex_json

# %%
hex_scheduled = _hex_json.loads("false")

# %%
hex_user_email = _hex_json.loads("\"example-user@example.com\"")

# %%
hex_run_context = _hex_json.loads("\"logic\"")

# %%
hex_timezone = _hex_json.loads("\"America/Mexico_City\"")

# %%
hex_project_id = _hex_json.loads("\"7ca3556b-51dc-4ea6-8aec-d37fca3b80e3\"")

# %%
hex_project_name = _hex_json.loads("\"1_euro2024_data_ingest\"")

# %%
hex_status = _hex_json.loads("\"\"")

# %%
hex_categories = _hex_json.loads("[]")

# %%
hex_color_palette = _hex_json.loads("[\"#4C78A8\",\"#F58518\",\"#E45756\",\"#72B7B2\",\"#54A24B\",\"#EECA3B\",\"#B279A2\",\"#FF9DA6\",\"#9D755D\",\"#BAB0AC\"]")

# %% [markdown]
# # HOL: Soccer Euro Cup 2024 Prediction ⚽⚽⚽
# **Building a Forecasting Model** with **Snowpark ML**
#
# ---
#
# In this HOL, we'll be using Snowflake Notebook and Snowpark ML to build out an end-to-end forecasting model, starting from data ingestion through to model deployment. We will address all the steps in ML development, and demonstrate the various capabilities Snowflake provides with Snowpark ML and its supporting MLOps capabilities.
#
#
# _The model aims to predict the winner of the Euro Cup 2024 — a polarizing subject for Matteo (Italy supporter) and Simon (England supporter)!_
# _Are you ready? Let's start!_
#
# ![image](https://i.gifer.com/embedded/download/BiCu.gif)

# %%
import hextoolkit
hex_snowflake_conn = hextoolkit.get_data_connection('SCS-SIMON-EURO2024')
session = hex_snowflake_conn.get_snowpark_session()

# %%
# add version tracking
app_tag = {
    "origin": "sf_sit",
    "name": "hol_sport_predict",
    "version": '{major: 1, minor: 0}'
}

session.query_tag = app_tag

# %% [markdown]
# ## Data Ingestion
# ---
# Once the dataset package is imported into the PUBLIC.DATA stage, we can import it in our staging tables.
#
# **(Time: 5 mins)**
#
# - Step through the notebook
# - Move data from __PUBLIC.DATA__ stage to tables
# - Get an understanding of the dataset loaded
# - Create additional cells to query the dataset further

# %%
# Ingesting Data.
# Using a nested SQL in a python script to ingest all dataset in one step.

# Create File Format for generic csv
session.sql(f'''
    CREATE OR REPLACE FILE FORMAT ff_generic_csv
        TYPE = CSV
        FIELD_DELIMITER = ','
        FIELD_OPTIONALLY_ENCLOSED_BY='"'
        PARSE_HEADER = True
        TRIM_SPACE = TRUE
        NULL_IF = ('NULL', 'null')
        ESCAPE_UNENCLOSED_FIELD= NONE
        ERROR_ON_COLUMN_COUNT_MISMATCH=false
        replace_invalid_characters=true
        date_format=auto
        time_format=auto
        timestamp_format=auto;
''').collect()

# Create File Format for results.csv (loaded adding unique id extra columns)
session.sql('''
    create or replace file format ff_results_csv
    	type=csv
        skip_header=1
        field_delimiter=','
        trim_space=true
        field_optionally_enclosed_by='"'
        replace_invalid_characters=true
        date_format=auto
        time_format=auto
        timestamp_format=auto; 
''').collect()

# Iterate on files to load into tables
tables = ["fixture", "rankings"]
for table in tables:
    session.sql(f'''
        CREATE OR REPLACE TABLE {table.upper()}
        USING TEMPLATE (
            SELECT ARRAY_AGG(object_construct(*))
            FROM TABLE(
                INFER_SCHEMA(
                    LOCATION=>'@data/{table}.csv',
                    FILE_FORMAT=>'ff_generic_csv',
                    IGNORE_CASE => TRUE
                )
            )
        );
    ''').collect()
    
    session.sql(f'''
        COPY INTO {table.upper()}
        FROM '@data/{table}.csv'
        FILE_FORMAT = ff_generic_csv
        MATCH_BY_COLUMN_NAME = CASE_INSENSITIVE;
    ''').collect()

# %%
session.sql(f'''
    create or replace table results as (
        select 
            ROW_NUMBER() OVER (ORDER BY $1) AS id,
            $1::date as date, 
            $2 as home_team, 
            $3 as away_team, 
            $4::integer as home_team_score, 
            $5::integer as away_team_score, 
            $6 as tournament, 
            $7 as city, 
            $8 as country,
            (CASE WHEN $9 = 'TRUE' then 1 ELSE 0 END) as neutral
        from 
            @data/results.csv
        (file_format => 'ff_results_csv')
    );
''').collect()
# Out:
# [Row(status='Table RESULTS successfully created.')]

# %%
# need to handle a country spelling difference for Turkey/Türkiye

session.sql(f'''
    update rankings 
        set country_full = 'Türkiye'
        where country_abrv = 'TUR';
''').collect()
# Out:
# [Row(number of rows updated=332, number of multi-joined rows updated=0)]

# %%
# let's check our newly created tables

session.sql(f'''
    show tables in schema public;
''').show()
# Out:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |"created_on"                      |"name"               |"database_name"  |"schema_name"  |"kind"  |"comment"                                           |"cluster_by"  |"rows"  |"bytes"  |"owner"   |"retention_time"  |"automatic_clustering"  |"change_tracking"  |"search_optimization"  |"search_optimization_progress"  |"search_optimization_bytes"  |"is_external"  |"enable_schema_evolution"  |"owner_role_type"  |"is_event"  |"budget"  |"is_hybrid"  |"is_iceberg"  |"is_dynamic"  |
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# |2024-05-29 06:44:18.764000-07:00  |FINAL_DATA_SCOOMBES  |EURO2024         |PUBLIC         |TABLE   |                                                    |              |13976   |134656   |SYSADMIN  |1                 |OFF                     |OFF                |OFF                    |NULL                            |NULL                         |N              |N                          |ROLE               |N           |NULL      |N            |N             |N             |
# |2024-05-29 13:08:44.238000-07:00  |FIXTURE              |EURO2024         |PUBLIC         |TABLE   |                                                    |              |51      |4096     |SYSADMIN  |1                 |OFF                     |OFF                |OFF                    |NULL                            |NULL                         |N              |N                          |ROLE               |N           |NULL      |N            |N             |N             |
# |2024-05-16 02:21:12.457000-07:00  |FIXTURE_MCONSOLI     |EURO2024         |PUBLIC         |TABLE   |The EURO2024.PUBLIC.MCONSOLI table holds footba...  |              |51      |4096     |SYSADMIN  |1                 |OFF                     |OFF                |OFF                    |NULL                            |NULL                         |N              |N                          |ROLE               |N           |NULL      |N            |N             |N             |
# |2024-05-29 09:15:10.521000-07:00  |FIXTURE_SCOOMBES     |EURO2024         |PUBLIC         |TABLE   |                                                    |              |51      |4096     |SYSADMIN  |1                 |OFF                     |OFF                |OFF                    |NULL                            |NULL                         |N              |N                          |ROLE               |N           |NULL      |N            |N             |N             |
# |2024-05-29 13:08:45.895000-07:00  |RANKINGS             |EURO2024         |PUBLIC         |TABLE   |                                                    |              |67261   |924160   |SYSADMIN  |1                 |OFF                     |OFF                |OFF                    |NULL                            |NULL                         |N              |N                          |ROLE               |N           |NULL      |N            |N             |N             |
# |2024-05-29 13:08:36.206000-07:00  |RESULTS              |EURO2024         |PUBLIC         |TABLE   |                                                    |              |46673   |977408   |SYSADMIN  |1                 |OFF                     |OFF                |OFF                    |NULL                            |NULL                         |N              |N                          |ROLE               |N           |NULL      |N            |N             |N             |
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
session.sql(f'''
  SELECT
    *
  FROM
    results
  WHERE
    home_team = 'England' 
    AND away_team = 'Germany'
    AND tournament = 'FIFA World Cup'
    AND YEAR(date) = 1966
''').show()
# Out:
# -------------------------------------------------------------------------------------------------------------------------------------------
# |"ID"  |"DATE"      |"HOME_TEAM"  |"AWAY_TEAM"  |"HOME_TEAM_SCORE"  |"AWAY_TEAM_SCORE"  |"TOURNAMENT"    |"CITY"  |"COUNTRY"  |"NEUTRAL"  |
# -------------------------------------------------------------------------------------------------------------------------------------------
# |6525  |1966-07-30  |England      |Germany      |4                  |2                  |FIFA World Cup  |London  |England    |0          |
# -------------------------------------------------------------------------------------------------------------------------------------------

# %%
# We also loaded the fixture of Euro Cup 2024 - these are the matches we'll predict the results. 
# Starting from group stage, through the knockout stage, up to the final.

session.table('fixture').show(51)
# Out:
# ---------------------------------------------------------------------------------------------------------------------------------------
# |"MATCH NUMBER"  |"ROUND NUMBER"  |"DATE"            |"LOCATION"             |"HOME TEAM"      |"AWAY TEAM"      |"GROUP"  |"RESULT"  |
# ---------------------------------------------------------------------------------------------------------------------------------------
# |1               |1               |14/06/2024 19:00  |Fußball Arena München  |Germany          |Scotland         |Group A  |NULL      |
# |2               |1               |15/06/2024 13:00  |Stadion Köln           |Hungary          |Switzerland      |Group A  |NULL      |
# |3               |1               |15/06/2024 16:00  |Olympiastadion         |Spain            |Croatia          |Group B  |NULL      |
# |4               |1               |15/06/2024 19:00  |BVB Stadion Dortmund   |Italy            |Albania          |Group B  |NULL      |
# |5               |1               |16/06/2024 13:00  |Volksparkstadion       |Poland           |Netherlands      |Group D  |NULL      |
# |6               |1               |16/06/2024 16:00  |Arena Stuttgart        |Slovenia         |Denmark          |Group C  |NULL      |
# |7               |1               |16/06/2024 19:00  |Arena AufSchalke       |Serbia           |England          |Group C  |NULL      |
# |8               |1               |17/06/2024 13:00  |Fußball Arena München  |Romania          |Ukraine          |Group E  |NULL      |
# |9               |1               |17/06/2024 16:00  |Frankfurt Stadion      |Belgium          |Slovakia         |Group E  |NULL      |
# |10              |1               |17/06/2024 19:00  |Düsseldorf Arena       |Austria          |France           |Group D  |NULL      |
# |11              |1               |18/06/2024 16:00  |BVB Stadion Dortmund   |Türkiye          |Georgia          |Group F  |NULL      |
# |12              |1               |18/06/2024 19:00  |RB Arena               |Portugal         |Czechia          |Group F  |NULL      |
# |13              |2               |19/06/2024 13:00  |Volksparkstadion       |Croatia          |Albania          |Group B  |NULL      |
# |14              |2               |19/06/2024 16:00  |Arena Stuttgart        |Germany          |Hungary          |Group A  |NULL      |
# |15              |2               |19/06/2024 19:00  |Stadion Köln           |Scotland         |Switzerland      |Group A  |NULL      |
# |16              |2               |20/06/2024 13:00  |Fußball Arena München  |Slovenia         |Serbia           |Group C  |NULL      |
# |17              |2               |20/06/2024 16:00  |Frankfurt Stadion      |Denmark          |England          |Group C  |NULL      |
# |18              |2               |20/06/2024 19:00  |Arena AufSchalke       |Spain            |Italy            |Group B  |NULL      |
# |19              |2               |21/06/2024 13:00  |Düsseldorf Arena       |Slovakia         |Ukraine          |Group E  |NULL      |
# |20              |2               |21/06/2024 16:00  |Olympiastadion         |Poland           |Austria          |Group D  |NULL      |
# |21              |2               |21/06/2024 19:00  |RB Arena               |Netherlands      |France           |Group D  |NULL      |
# |22              |2               |22/06/2024 13:00  |Volksparkstadion       |Georgia          |Czechia          |Group F  |NULL      |
# |23              |2               |22/06/2024 16:00  |BVB Stadion Dortmund   |Türkiye          |Portugal         |Group F  |NULL      |
# |24              |2               |22/06/2024 19:00  |Stadion Köln           |Belgium          |Romania          |Group E  |NULL      |
# |25              |3               |23/06/2024 19:00  |Frankfurt Stadion      |Switzerland      |Germany          |Group A  |NULL      |
# |26              |3               |23/06/2024 19:00  |Arena Stuttgart        |Scotland         |Hungary          |Group A  |NULL      |
# |27              |3               |24/06/2024 19:00  |Düsseldorf Arena       |Albania          |Spain            |Group B  |NULL      |
# |28              |3               |24/06/2024 19:00  |RB Arena               |Croatia          |Italy            |Group B  |NULL      |
# |29              |3               |25/06/2024 16:00  |Olympiastadion         |Netherlands      |Austria          |Group D  |NULL      |
# |30              |3               |25/06/2024 16:00  |BVB Stadion Dortmund   |France           |Poland           |Group D  |NULL      |
# |31              |3               |25/06/2024 19:00  |Stadion Köln           |England          |Slovenia         |Group C  |NULL      |
# |32              |3               |25/06/2024 19:00  |Fußball Arena München  |Denmark          |Serbia           |Group C  |NULL      |
# |33              |3               |26/06/2024 16:00  |Frankfurt Stadion      |Slovakia         |Romania          |Group E  |NULL      |
# |34              |3               |26/06/2024 16:00  |Arena Stuttgart        |Ukraine          |Belgium          |Group E  |NULL      |
# |35              |3               |26/06/2024 19:00  |Arena AufSchalke       |Georgia          |Portugal         |Group F  |NULL      |
# |36              |3               |26/06/2024 19:00  |Volksparkstadion       |Czechia          |Türkiye          |Group F  |NULL      |
# |37              |Round of 16     |29/06/2024 16:00  |Olympiastadion         |2A               |2B               |NULL     |NULL      |
# |38              |Round of 16     |29/06/2024 19:00  |BVB Stadion Dortmund   |1A               |2C               |NULL     |NULL      |
# |39              |Round of 16     |30/06/2024 16:00  |Arena AufSchalke       |1C               |3D/E/F           |NULL     |NULL      |
# |40              |Round of 16     |30/06/2024 19:00  |Stadion Köln           |1B               |3A/D/E/F         |NULL     |NULL      |
# |41              |Round of 16     |01/07/2024 16:00  |Düsseldorf Arena       |2D               |2E               |NULL     |NULL      |
# |42              |Round of 16     |01/07/2024 19:00  |Frankfurt Stadion      |1F               |3A/B/C           |NULL     |NULL      |
# |43              |Round of 16     |02/07/2024 16:00  |Fußball Arena München  |1E               |3A/B/C/D         |NULL     |NULL      |
# |44              |Round of 16     |02/07/2024 19:00  |RB Arena               |1D               |2F               |NULL     |NULL      |
# |45              |Quarter Finals  |05/07/2024 16:00  |Arena Stuttgart        |To be announced  |To be announced  |NULL     |NULL      |
# |46              |Quarter Finals  |05/07/2024 19:00  |Volksparkstadion       |To be announced  |To be announced  |NULL     |NULL      |
# |47              |Quarter Finals  |06/07/2024 16:00  |Düsseldorf Arena       |To be announced  |To be announced  |NULL     |NULL      |
# |48              |Quarter Finals  |06/07/2024 19:00  |Olympiastadion         |To be announced  |To be announced  |NULL     |NULL      |
# |49              |Semi Finals     |09/07/2024 19:00  |Fußball Arena München  |To be announced  |To be announced  |NULL     |NULL      |
# |50              |Semi Finals     |10/07/2024 19:00  |BVB Stadion Dortmund   |To be announced  |To be announced  |NULL     |NULL      |
# |51              |Final           |14/07/2024 19:00  |Olympiastadion         |To be announced  |To be announced  |NULL     |NULL      |
# ---------------------------------------------------------------------------------------------------------------------------------------
